# %% [markdown]
# # 2. MINTvent - Informatik
#
# Hallo zusammen!
#
# Wir befinden uns nun in der zweiten Adventswoche - Zeit für ein kleines Informatik-Rätsel! 🎄🖥️
#
# Heute werdet ihr etwas ganz Besonderes machen: Ihr werdet euer allererstes eigenes Programm schreiben, lernen was RGB ist und wie es funktioniert! Aber bevor wir loslegen, schauen wir uns an, womit sich die Informatik eigentlich beschäftigt und warum Programmieren so spannend ist. Am Ende werdet ihr in der Lage sein, eure eigenen kleinen Nachrichten mit einem Computer zu erstellen und Farbe in den Code zu bringen -  klingt cool, oder?
#
# ---

# %% [markdown]
# # Einführung: Was ist Informatik und warum Programmieren?
#
# Das Wort „Informatik“ setzt sich aus zwei Begriffen zusammen: Information und Mathematik (oder manchmal auch „Automatik“). Doch was bedeutet das genau?
# Wenn man das mal googelt trifft man schnell auf die folgende Definition:
#
# > *Informatik ist die Wissenschaft davon, wie Informationen gespeichert, verarbeitet und dargestellt werden können – oft mit Hilfe von Computern.*
#
# Das klingt erstmal ziemlich trocken, aber Informatik ist überall! Hier ein paar Beispiele aus unserem Alltag:
#
# - 📱 Dein Handy: Wenn du eine Nachricht schreibst, berechnet dein Smartphone blitzschnell, wie die Buchstaben auf dem Bildschirm angezeigt werden und wohin deine Nachricht geschickt wird.
# - 🧠 ✨ Künstliche Intelligenz: Ob ein Sprachassistent wie Alexa oder eine App, die ein Bild von dir in ein Gemälde verwandelt – Informatik steckt dahinter.
# - 🎮 Videospiele: Jedes Spiel, jede Animation und jede Interaktion basiert auf Programmierung.
# - 🗺 🧭 Navigation: Dank Informatik findest du den kürzesten Weg von A nach B, und dein Handy weiß sogar, wo du bist.
#
# Einfach gesagt: Informatik ermöglicht es Computern, Apps und Maschinen, Aufgaben für uns zu übernehmen und uns bei der Arbeit zu unterstützen.
#
# Aber Moment mal, was hat das mit Programmieren zu tun?
# Damit ein Computer etwas für uns tun kann, müssen wir ihm **genau** sagen, was er machen soll. Computer können von sich aus nicht denken – sie brauchen klare Anweisungen. Diese Anweisungen geben wir ihnen in Form von Programmen.
# Ein Programm ist eine Art Rezept mit einer Reihe von Befehlen, die der Computer Schritt für Schritt ausführt. Programmieren bedeutet also, solche Rezepte zu schreiben.
#
# Dabei ist es wichtig zu wissen, dass es nicht nur eine, sondern viele verschiedene Programmiersprachen gibt – genau wie bei den Sprachen, die wir Menschen sprechen. Beispiele für solche Programmiersprachen sind Python, Java, C, MATLAB und viele mehr. Ob du nun Python oder Englisch benutzt, das Ziel ist immer dasselbe: **Kommunikation**. Wenn du mit einem Computer sprechen möchtest, nutzt du eine Programmiersprache. Wenn du mit anderen Menschen kommunizierst, greifst du stattdessen zu Deutsch, Englisch, Französisch,... 👀

# %% [markdown]
# # Das erste selbstgeschriebene Programm
#
# First things first: bevor wir zum eigentlichen Thema über RGB Farbcodierung kommen, schreibt ihr hier euer erstes eigenes Programm.
#
# Für heute verwenden wir die Programmiersprache Python. Um etwas (zum Beispiel einen Text) anzeigen zu lassen, verwendet man die Funtkion *print*.
#
# Wenn ich also "Liebe Grüße an das Chrsitkind." ausgeben möchte, dann kann ich das folgendermaßen tun:

# %%
print('Liebe Grüße an das Christkind.')

# %% [markdown]
# Beachte: Zuerst kommt die Funktion, die wir verwenden möchten, also *print*.
# In Klammern steht dann, was wir der Funktion geben. Da es sich hierbei um einen **Text** handelt, **muss** dieser in **einfachen Anführungszeichen ' stehen**.
#
# Wenn du jetzt oben in der Leiste schaust, solltest du dort einen "Play" Button ▶ entdecken. Programmierer nennen das "run", wenn sie einen Code ausführen möchten. Klicke zuerst in das Feld, welches du ausführen möchtest (= also dort wo gerade print('Liebe Grüße ... steht). Drücke dann auf ▶, so verarbeitet der Rechner, was du ihm gegeben hast. Da die Funktion *print* das, was in den Klammern ist, einfach ausgibt, solltest du nun genau diesen Text auch unten drunter sehen.
#
# Überall wo du ein **# TODO** entdeckst, gibt es etwas, das du ausprobieren kannst. Alles, was in der gleichen Zeile nach einem # steht, erscheint grau und ist ein **Kommentar**.
#
#
# > *Kommentare sind für uns Menschen, damit wir uns Notizen machen können. Das ist besonders hilfreich, wenn mehr als eine Person an einem Programm arbeitet oder man selbst nach längerer Zeit nachvollziehen möchte, was man sich bei dem Code gedacht hat.
# Der Computer wird den Text allerdings gekonnt ignorieren.*
#
#
#
# Im folgenden Feld kannst du nun dein erstes eigenes Programm schreiben und ausführen. Orientiere dich dafür an dem Besipiel von oben.
#
#
# ---
#
#
# Aufgabe:
# 1. Schreibe einen Code, der den Text "Hello World!" ausgeben kann.
# 2. Erstelle darunter einen Kommentar mit deinem Namen.
# 2. Führe deinen Code aus.

# %%
# TODO: Gib hier den Text "Hello World!" aus.

# %% [markdown]
# Wenn alles geklappt hat, sollte direkt über dieser Zeile "Hello World!"stehen. Dein Name erscheint aber nur oben im Kommentar.
#
# In diesem Fall: Herzlichen Glückwunsch zu deinem ersten Programm! 🥳
#
#
# Falls etwas nicht funktioniert hat kannst du gerne selbst experimentieren oder im Chat auf Cybermentor nachfragen. 🤗

# %% [markdown]
# # Was ist RGB?
#
# RGB steht für Rot Grün/Gelb und Blau. Unser Auge hat Zapfen, womit es verschiedene Farben wahrnehmen kann. Mehr dazu beispielsweise hier: [Video zum Farbensehen (~3.5 min)](https://www.youtube.com/watch?v=T4p9wfOIPS4)
#
#
# Dein Bildschrim macht sich genau das zu nutzen. Er besteht aus ganz vielen Pixeln (= kleine Quadrate). Jedes Pixel hat dabei drei Kanäle:
# - einen roten 🔴
# - einen grünen 🟢
# - einen blauen 🔵
#
# Auf dem folgenden Bild sieht man mehrfach vergrößert, wie eine Webseite auf einem Bildschirm dargestellt wird. Je mehr man reinzoomt, desto besser erkennt man, dass es viele Quadrate sind, die direkt aneinandergereiht sind. Jedes dieser Quadrate, also Pixel, hat die drei genannten Farben. Wenn man genauer hinschaut, dann sieht man, dass die Helligkeit variiert. Zum Beispiel zur Darstellung des schwarzen Textes ist sie geringer als für die Darstellung des helleren Hintergrundes.
#
# ![](https://referate.mezdata.de/sj2009/lcd_paul-brosinsky/res-wikipedia/Liquid_Crystal_Display_Macro_Example_zoom_2.jpg)
#
# Je nachdem, wie intensiv, also wie hell jeder einzelne Kanal eingestellt wird, so sehen wir eine andere Farbe. Das kannst Du dir vorstellen wie einen Wasserfarbkasten im Kunstunterricht. Wenn du Rot und Blau mischst, bekommst du violett. Wenn du etwas mehr Rot hinzufügst, wird es eher heller und rosiger. Wenn du aber mehr Blau hinzufügst, dann wird die Farbe entsprechend ein dunkleres Violett.
#
# ![](https://cdn.britannica.com/89/234589-050-0E6E9D4B/color-wheel-additive.jpg)
#
# Die **Intensitäten** (= wie viel Farbe gibst du hinzu) lassen sich in RGB in einem **Intervall von 0 bis 255** steuern.
# - 0 bedeutet, gar keine Farbe dazugeben
# - 255 bedeutet, maximal viel Farbe dazugeben
#
#
# ---
#
# Aufgabe:
#
# Hier ist ein Stück Code bereits vorbereitet. Du kannst die Werte für RGB selbst einstellen und ausprobieren, welche Farbe dabei auskommt. Bearbeite dafür die drei Zahlen und führe das Programm dann aus, indem du wie vorhin auf den "Run" Button ▶ oben links drückst. Untendrunter sollte dann die aktuelle Farbe erscheinen.
#
# Probiere aus und **notiere**, welche RGB-Werte jeweils du für folgendes brauchst:
# 1. Wie bekommst du ein reines rot?
# 2. ... und ein reines grün?
# 3. ... ein reines blau?
# 4. Welche Kombination gibt dir deine Lieblingsfarbe?

# %%
import matplotlib.pyplot as plt

# TODO: Probiere hier die Werte für red, green und blue zu verändern
red = 0
green = 0
blue =  0

rgb_color = (red/255, green/255, blue/255) # diese Zeile(n) bitte NICHT verändern

# Create a figure and axis
fig, ax = plt.subplots(figsize=(2, 2))

# Plot a rectangle filled with the RGB color
ax.add_patch(plt.Rectangle((0, 0), 1, 1, color=rgb_color))

# Remove axes for better visual appeal
ax.set_axis_off()

# Display the plot
plt.show()

# %% [markdown]
# # Farbe für die Welt
#
# Nach so viel Input wird es Zeit für das Herzstück des heutigen Rätsels: Wir malen einen Weihnachtsbaum. 🎄
#
# Auch hier gibt es bereits einen vorgeschriebenen Code. Lasst euch von der Länge nicht abschrecken. Diese Funktionen zeichnen Stück für Stück mit verschiedenen geometrischen Figuren (= Dreiecke, Rechtecke, Kreise,...), die Silhouette des Baums und der ganzen Dekorationen.
#
#
#
# ---
#
#
# Aufgabe:
#
# Der Weihnachtsbaum ist leider relativ farblos geraten. Damit das Ganze etwas festlicher wird, müssen Farben her. Orientiere dich an den # TODO's im Code und gib deine Werte für Rot, Grün und Blau ein. Wie das Ganze ausschaut, siehst du erneut beim Ausführen des Codes, also wenn du auf den "Run" Button ▶ drückst.
# Sobald du mit dem Ergebnis zufrieden bist, erstelle einen Screenshot oder fotografiere deinen Weihnachtsbaum. So können wir uns später gemeinsam die verschiedenen Ergebnisse anschauen. ✨

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_christmas_tree():
    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(6, 8))
    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-0.5, 1.75)
    ax.set_aspect('equal', adjustable ='box')
    ax.axis('off')  # Turn off axes

    # TODO: Die Tanne selbst. Setze die Farben für die drei Dreiecke:
    erstesDreieck_red = 0
    erstesDreieck_green = 0
    erstesDreieck_blue = 0

    zweitesDreieck_red = 0
    zweitesDreieck_green = 0
    zweitesDreieck_blue = 0

    drittesDreieck_red = 0
    drittesDreieck_green = 0
    drittesDreieck_blue = 0

    tree_colors = [(erstesDreieck_red/255, erstesDreieck_green/255, erstesDreieck_blue/255),
                    (zweitesDreieck_red/255, zweitesDreieck_green/255, zweitesDreieck_blue/255),
                    (drittesDreieck_red/255, drittesDreieck_green/255, drittesDreieck_blue/255)]
    base_widths = [1.5, 1.2, 0.9]
    heights = [0.5, 0.4, 0.3]

    # Start position for the bottom of the tree
    current_y = 0

    for width, height, color in zip(base_widths, heights, tree_colors):
        # Define the triangle vertices
        vertices = [
            (0, current_y + height),  # Top of the triangle
            (-width / 2, current_y),  # Bottom-left
            (width / 2, current_y)  # Bottom-right
        ]
        # Add the triangle as a polygon
        ax.add_patch(patches.Polygon(vertices, closed=True, color=color))
        # Update the current_y to the top of this layer
        current_y += height

    # TODO: Der Baumstamm. Setze hier die RGB Werte für den Stamm:
    stamm_red = 0
    stamm_green = 0
    stamm_blue = 0

    trunk_color = (stamm_red/255, stamm_green/255, stamm_blue/255)
    ax.add_patch(patches.Rectangle(
        (-0.1, -0.5), 0.2, 0.5, color=trunk_color
    ))

    # TODO: Die Baumspitze bekommt einen Stern. Setze auch hier die Farbe:
    stern_red = 0
    stern_green = 0
    stern_blue = 0
    star_color = (stern_red/255, stern_green/255, stern_blue/255)
    ax.add_patch(patches.RegularPolygon(
        (0, current_y), numVertices=5, radius=0.1, orientation=0, color=star_color
    ))

    # TODO: Schick wird's erst mit Baumschmuck. Hier kannst du sogar drei verschiedene Farben erstellen:
    kugelFarbe1_red = 0
    kugelFarbe1_green = 0
    kugelFarbe1_blue = 0

    kugelFarbe2_red = 0
    kugelFarbe2_green = 0
    kugelFarbe2_blue = 0

    kugelFarbe3_red = 0
    kugelFarbe3_green = 0
    kugelFarbe3_blue = 0

    decoration_colors = [(kugelFarbe1_red/255, kugelFarbe1_green/255, kugelFarbe1_blue/255),
                          (kugelFarbe2_red/255, kugelFarbe2_green/255, kugelFarbe2_blue/255),
                          (kugelFarbe3_red/255, kugelFarbe3_green/255, kugelFarbe3_blue/255)]
    decorations = [
        (0.3, 0.7), (-0.4, 0.6), (0.5, 0.5),
        (-0.3, 0.3), (0.1, 0.2), (-0.5, 0.1)
    ]
    for (x, y), color in zip(decorations, decoration_colors * 2):
        ax.add_patch(patches.Circle((x, y), 0.05, color=color))

    # Display the plot
    plt.show()

# Draw the Christmas tree
draw_christmas_tree()
